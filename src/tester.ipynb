# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import torch

# %%
mel = np.load("/mnt/d/Speech Data/LJ/LJSpeech-1.1/mels/LJ001-0002.mel.npy")

# %%
wav, real_sr = librosa.load("/mnt/d/Speech Data/LJ/LJSpeech-1.1/wavs/LJ001-0002.wav")

# %%
sr = 22050
n_fft = 2048
hop_length = 250
win_length = n_fft
n_mels = 80
fmin = 0.0
fmax = None

# %%
mel_filter = librosa.filters.mel(sr=sr, n_fft=n_fft, n_mels=n_mels, 
                                 fmin=fmin, 
                                 fmax=fmax)

# %%
mel_real = librosa.feature.melspectrogram(y=wav, 
                                       sr=sr,
                                       n_fft=n_fft,
                                       hop_length=hop_length,
                                       win_length=win_length,
                                       n_mels=n_mels
                                       )

# %%
(len(wav) - win_length)/hop_length
# Out:
# 159.348

# %%
sns.heatmap(mel)
# Out:
# <Axes: >

# %%
sns.heatmap(mel_real, vmin=0, vmax=100)
# Out:
# <Axes: >

# %%
a = torch.randn(3,5,4)
b = torch.randn(3,2,4)

# %%
nt = torch.nested.nested_tensor([a,b], layout=torch.jagged)
