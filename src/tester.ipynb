# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import librosa

# %%
mel = np.load("/mnt/d/Speech Data/LJ/LJSpeech-1.1/mels/LJ001-0002.mel.npy")

# %%
wav, real_sr = librosa.load("/mnt/d/Speech Data/LJ/LJSpeech-1.1/wavs/LJ001-0002.wav")

# %%
sr = 22050
n_fft = 2048
hop_length = 250
win_length = n_fft
n_mels = 80
fmin = 0.0
fmax = None

# %%
mel_filter = librosa.filters.mel(sr=sr, n_fft=n_fft, n_mels=n_mels, 
                                 fmin=fmin, 
                                 fmax=fmax)

# %%
mel_real = librosa.feature.melspectrogram(y=wav, 
                                       sr=sr,
                                       n_fft=n_fft,
                                       hop_length=hop_length,
                                       win_length=win_length,
                                       )
# Out:
# /home/zak/Github/MultispeakerTTS/.venv/lib/python3.12/site-packages/librosa/feature/spectral.py:2148: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)

# %%
mel.shape
# Out:
# (128, 1025)

# %%
sns.heatmap(mel)
# Out:
# <Axes: >

# %%
sns.heatmap(mel_real)
# Out:
# <Axes: >
